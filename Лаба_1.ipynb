# %% [markdown]
# Практическая работа 3. Обработка данных из файла

# %% [markdown]
# Коршиков Иван Сергеевич ПИН-б-о-22-1 09.03.03 Прикладная информатика

# %% [markdown]
# Вариант 12

# %% [markdown]
# Цель работы: научиться писать простейшие скрипты Python, используя
# простейшие возможности языка.

# %%
g = 10
h = 5
d17 = 2

print(f"g = {g}, type(g) = {type(g)}")
print(f"h = {h}, type(h) = {type(h)}")
print(f"d17 = {d17}, type(d17) = {type(d17)}")
# Out:
# g = 10, type(g) = <class 'int'>
# h = 5, type(h) = <class 'int'>
# d17 = 2, type(d17) = <class 'int'>

# %%
ee = (g * h / d17) + (d17 / h) - (g + d17 + h) / 4
print(f"ee = {ee}") #
print(f"Type of ee: {type(ee)}")
# Out:
# ee = 21.15
# Type of ee: <class 'float'>
