# %% [markdown]
# **ПРАКТИЧЕСКАЯ РАБОТА 9. ПЕРВИЧНЫЙ АНАЛИЗ ДАННЫХ**

# %% [markdown]
# Коршиков Иван Сергеевич ПИН-б-о-22-1 09.03.03 Прикладная информатика

# %% [markdown]
# Цель лабораторной работы: изучение программных средств для организации рабочего места специалиста по анализу данных и машинному обучению. Основные задачи: – получение программного доступа к данным, содержащимся в источниках различного типа; – выполнение предварительного анализа данных и получение обобщенных характеристик наборов данных; – исследование простых методов визуализации данных; – изучение основных библиотек Python для работы с данными.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = np.genfromtxt("/content/adult.data", delimiter=",")
print(data)
# Out:
# [[3.90000e+01         nan 7.75160e+04 ... 4.00000e+01         nan
#           nan]
#  [5.00000e+01         nan 8.33110e+04 ... 1.30000e+01         nan
#           nan]
#  [3.80000e+01         nan 2.15646e+05 ... 4.00000e+01         nan
#           nan]
#  ...
#  [5.80000e+01         nan 1.51910e+05 ... 4.00000e+01         nan
#           nan]
#  [2.20000e+01         nan 2.01490e+05 ... 2.00000e+01         nan
#           nan]
#  [5.20000e+01         nan 2.87927e+05 ... 4.00000e+01         nan
#           nan]]

# %%
print("Data type : ", type(data))
print("Data shape : ", data.shape )
print(data[:10])
# Out:
# Data type :  <class 'numpy.ndarray'>
# Data shape :  (32561, 15)
# [[3.90000e+01         nan 7.75160e+04         nan 1.30000e+01         nan
#           nan         nan         nan         nan 2.17400e+03 0.00000e+00
#   4.00000e+01         nan         nan]
#  [5.00000e+01         nan 8.33110e+04         nan 1.30000e+01         nan
#           nan         nan         nan         nan 0.00000e+00 0.00000e+00
#   1.30000e+01         nan         nan]
#  [3.80000e+01         nan 2.15646e+05         nan 9.00000e+00         nan
#           nan         nan         nan         nan 0.00000e+00 0.00000e+00
#   4.00000e+01         nan         nan]
#  [5.30000e+01         nan 2.34721e+05         nan 7.00000e+00         nan
#           nan         nan         nan         nan 0.00000e+00 0.00000e+00
#   4.00000e+01         nan         nan]
#  [2.80000e+01         nan 3.38409e+05         nan 1.30000e+01         nan
#           nan         nan         nan         nan 0.00000e+00 0.00000e+00
# ...

# %%
data2 = np.genfromtxt('/content/adult.data', delimiter=",", dtype=None, encoding='utf-8')

# %%
print(data2.shape)
print(type(data2))
print(type(data2[0]))
print(type(data2[0][4]))
print(data2[:14])
# Out:
# (32561,)
# <class 'numpy.ndarray'>
# <class 'numpy.void'>
# <class 'numpy.int64'>
# [(39, ' State-gov',  77516, ' Bachelors', 13, ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', ' Male',  2174, 0, 40, ' United-States', ' <=50K')
#  (50, ' Self-emp-not-inc',  83311, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', ' Male',     0, 0, 13, ' United-States', ' <=50K')
#  (38, ' Private', 215646, ' HS-grad',  9, ' Divorced', ' Handlers-cleaners', ' Not-in-family', ' White', ' Male',     0, 0, 40, ' United-States', ' <=50K')
#  (53, ' Private', 234721, ' 11th',  7, ' Married-civ-spouse', ' Handlers-cleaners', ' Husband', ' Black', ' Male',     0, 0, 40, ' United-States', ' <=50K')
#  (28, ' Private', 338409, ' Bachelors', 13, ' Married-civ-spouse', ' Prof-specialty', ' Wife', ' Black', ' Female',     0, 0, 40, ' Cuba', ' <=50K')
# ...

# %%
dt0 = ("i4,f8,f8,f8,f8,f8,f8,f8,f8,f8,f8,f8,f8,f8")

# %%
data1 = np.genfromtxt("/content/adult.data", delimiter=",", dtype=dt0)

# %%
print(data1.shape)
print(type(data1))
print(type(data1[0]))
print(type(data1[0][4]))
print(data1[:10])
# Out:
# (32561,)
# <class 'numpy.ndarray'>
# <class 'numpy.void'>
# <class 'numpy.float64'>
# [(39, nan,  77516., nan, 13., nan, nan, nan, nan, nan,  2174., 0., 40., nan)
#  (50, nan,  83311., nan, 13., nan, nan, nan, nan, nan,     0., 0., 13., nan)
#  (38, nan, 215646., nan,  9., nan, nan, nan, nan, nan,     0., 0., 40., nan)
#  (53, nan, 234721., nan,  7., nan, nan, nan, nan, nan,     0., 0., 40., nan)
#  (28, nan, 338409., nan, 13., nan, nan, nan, nan, nan,     0., 0., 40., nan)
#  (37, nan, 284582., nan, 14., nan, nan, nan, nan, nan,     0., 0., 40., nan)
#  (49, nan, 160187., nan,  5., nan, nan, nan, nan, nan,     0., 0., 16., nan)
#  (52, nan, 209642., nan,  9., nan, nan, nan, nan, nan,     0., 0., 45., nan)
#  (31, nan,  45781., nan, 14., nan, nan, nan, nan, nan, 14084., 0., 50., nan)
#  (42, nan, 159449., nan, 13., nan, nan, nan, nan, nan,  5178., 0., 40., nan)]

# %%
age = []
fnlwgt = []
education_num = []
capital_gain = []
capital_loss = []
hours_per_week = []

# %%
for dot in data1:
    age.append(dot[0])
    fnlwgt.append(dot[2])
    education_num.append(dot[4])
    capital_gain.append(dot[10])
    capital_loss.append(dot[11])
    hours_per_week.append(dot[12])

# %%
print(fnlwgt.count(1))
print(age.count(2))
print(age.count(3))
# Out:
# 0
# 0
# 0

# %%
plt.figure(1) # Это мы узнали сколько зарабатывают > 50000 в год работаю опредёлнное время суток
class_1 =plt.plot(age[:59], hours_per_week[:59], "ro", label="1")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=1.)
plt.xlabel("age")
plt.ylabel("hours_per_week")
# Out:
# Text(0, 0.5, 'hours_per_week')

# %%
import pandas as pd
import matplotlib.pyplot as plt

condition = df['age'] > 40

df_subset = df[condition]

x_feature = 'education_num'
y_feature = 'hours_per_week'

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_subset, x=x_feature, y=y_feature, hue='class')
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.show()

# %% [markdown]
# «На этом графике рассеяния показана взаимосвязь между уровнем образования (education_num) и количеством рабочих часов в неделю (hours_per_week) для людей старше 40 лет, при этом группы различаются в зависимости от их принадлежности к классу. Это подмножество было выбрано для изучения потенциальных возрастных закономерностей в рабочих привычках».
